# %%
import pandas as pd
import folium

def creer_carte_accidents(fichier_csv, nom_carte_html, centre=[44.8378, -0.5792], zoom=12):
    df = pd.read_csv(fichier_csv)
    
    # Nettoyage / Conversion coordonnées
    df["lat"] = df["lat"].astype(str).str.replace(",", ".")
    df["long"] = df["long"].astype(str).str.replace(",", ".")
    
    # Conversion en float, les erreurs deviennent NaN
    df["lat"] = pd.to_numeric(df["lat"], errors='coerce')
    df["long"] = pd.to_numeric(df["long"], errors='coerce')
    
    # Supprimer les lignes sans coordonnées valides
    df = df.dropna(subset=["lat", "long"])
    
    print(f"Nombre d'accidents avec coordonnées valides : {len(df)}")
    
    # Création carte centrée sur Bordeaux
    carte = folium.Map(location=centre, zoom_start=zoom)
    
    # Ajout des markers
    for _, row in df.iterrows():
        folium.CircleMarker(
            location=[row["lat"], row["long"]],
            radius=3,
            color='red',
            fill=True,
            fill_opacity=0.7,
            popup=f"Accident {row['Num_Acc']}"
        ).add_to(carte)
    
    carte.save(nom_carte_html)
    print(f"Carte enregistrée : {nom_carte_html}")
    return carte

# %%
carte_2005 = creer_carte_accidents("2005/accidents_bordeaux_2005.csv", "carte_bordeaux_cub_2005.html")
carte_2005
# Out:
# Nombre d'accidents avec coordonnées valides : 582
# Carte enregistrée : carte_bordeaux_cub_2005.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70c4f9d9e78a9b922077ca1f304df939 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70c4f9d9e78a9b922077ca1f304df939&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70c4f9d9e78a9b922077ca1f304df939 = L.map(
#                 &quot;map_70c4f9d9e78a9b922077ca1f304df939&quot;,
#                 {
#                     center: [44.8378, -0.5792],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9543064ecda5f007529fad7fc3203854 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9543064ecda5f007529fad7fc3203854.addTo(map_70c4f9d9e78a9b922077ca1f304df939);
#
#
#             var circle_marker_dbc901be0819de2a711ee5772047aca0 = L.circleMarker(
#                 [0.0, 0.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_70c4f9d9e78a9b922077ca1f304df939);
#
#
#         var popup_c5755034ee26a38c977ae98094c45ea1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e751d5dba65ecbe24693f719da40dab = $(`&lt;div id=&quot;html_2e751d5dba65ecbe24693f719da40dab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accident 200500000467&lt;/div&gt;`)[0];
#                 popup_c5755034ee26a38c977ae98094c45ea1.setContent(html_2e751d5dba65ecbe24693f719da40dab);
#
#
#
#         circle_marker_dbc901be0819de2a711ee5772047aca0.bindPopup(popup_c5755034ee26a38c977ae98094c45ea1)
#         ;
#
#
#
#
#             var circle_marker_782fd5e1a375ff2c27870fa2390ba00b = L.circleMarker(
#                 [0.0, 0.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_70c4f9d9e78a9b922077ca1f304df939);
#
#
#         var popup_5c76c799e5531df9a6da3e08ad178e63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b7f7e74ff87281feac0a01f1a4a76a3 = $(`&lt;div id=&quot;html_4b7f7e74ff87281feac0a01f1a4a76a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accident 200500000468&lt;/div&gt;`)[0];
#                 popup_5c76c799e5531df9a6da3e08ad178e63.setContent(html_4b7f7e74ff87281feac0a01f1a4a76a3);
#
#
#
#         circle_marker_782fd5e1a375ff2c27870fa2390ba00b.bindPopup(popup_5c76c799e5531df9a6da3e08ad178e63)
#         ;
#
#
#
#
#             var circle_marker_9ca605a9c3f0b2565f85aa382f049240 = L.circleMarker(
#                 [0.0, 0.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_70c4f9d9e78a9b922077ca1f304df939);
#
#
#         var popup_84506365f9649c255ef2e07365eb74ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4da6f2a9150d9b92118a0525131a6922 = $(`&lt;div id=&quot;html_4da6f2a9150d9b92118a0525131a6922&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accident 200500000469&lt;/div&gt;`)[0];
#                 popup_84506365f9649c255ef2e07365eb74ec.setContent(html_4da6f2a9150d9b92118a0525131a6922);
#
#
#
#         circle_marker_9ca605a9c3f0b2565f85aa382f049240.bindPopup(popup_84506365f9649c255ef2e07365eb74ec)
#         ;
#
#
#
#
#             var circle_marker_9f19a1c6dcd32cdb82d8520d46a59177 = L.circleMarker(
#                 [0
